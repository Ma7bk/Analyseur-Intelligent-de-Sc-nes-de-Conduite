# %%
# !pip install ultralytics gdown -q

import torch
print(f'CUDA disponible : {torch.cuda.is_available()}')
if torch.cuda.is_available():
    print(f'GPU : {torch.cuda.get_device_name(0)}')
else:
    print('ATTENTION : Pas de GPU !')
    print('Aller dans Settings → Accelerator → GPU T4 x2')
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 20.6 MB/s eta 0:00:00
# CUDA disponible : True
# GPU : Tesla T4

# %%
import os

DATASET_PATH = '/kaggle/input/datasets/benkhalifamahmoud/bdd100k-highway/bdd100k_highway'

TRAIN_IMG = os.path.join(DATASET_PATH, 'images', 'train')
VAL_IMG   = os.path.join(DATASET_PATH, 'images', 'val')
TRAIN_LBL = os.path.join(DATASET_PATH, 'labels', 'train')
VAL_LBL   = os.path.join(DATASET_PATH, 'labels', 'val')

n_train_img = len([f for f in os.listdir(TRAIN_IMG) if f.endswith('.jpg')])
n_val_img   = len([f for f in os.listdir(VAL_IMG)   if f.endswith('.jpg')])
n_train_lbl = len([f for f in os.listdir(TRAIN_LBL) if f.endswith('.json')])
n_val_lbl   = len([f for f in os.listdir(VAL_LBL)   if f.endswith('.json')])

print(f'Train : {n_train_img} images | {n_train_lbl} labels')
print(f'Val   : {n_val_img} images | {n_val_lbl} labels')
# Out:
# Train : 17414 images | 17414 labels
# Val   : 2499 images | 2499 labels

# %%
import json
import shutil

CLASS_MAP = {
    'car':           0,
    'truck':         1,
    'bus':           2,
    'pedestrian':    3,
    'rider':         4,
    'traffic sign':  5,
    'traffic light': 6
}

IMG_W, IMG_H = 1280, 720

OUT_TRAIN_LBL = '/kaggle/working/dataset/labels/train'
OUT_VAL_LBL   = '/kaggle/working/dataset/labels/val'
OUT_TRAIN_IMG = '/kaggle/working/dataset/images/train'
OUT_VAL_IMG   = '/kaggle/working/dataset/images/val'

for folder in [OUT_TRAIN_LBL, OUT_VAL_LBL, OUT_TRAIN_IMG, OUT_VAL_IMG]:
    os.makedirs(folder, exist_ok=True)


def convert_split(lbl_dir, img_src_dir, out_lbl_dir, out_img_dir, split):
    json_files = [f for f in os.listdir(lbl_dir) if f.endswith('.json')]
    converted, skipped = 0, 0

    print(f'Conversion {split} : {len(json_files)} fichiers...')

    for i, jf in enumerate(json_files):
        with open(os.path.join(lbl_dir, jf), 'r') as f:
            data = json.load(f)

        frames = data.get('frames', [])
        if not frames:
            skipped += 1
            continue
        objects = frames[0].get('objects', [])

        yolo_lines = []
        for obj in objects:
            cat = obj.get('category', '')
            if cat not in CLASS_MAP:
                continue
            box = obj.get('box2d')
            if not box:
                continue

            x1, y1, x2, y2 = box['x1'], box['y1'], box['x2'], box['y2']
            x_center = min(max((x1 + x2) / (2 * IMG_W), 0), 1)
            y_center = min(max((y1 + y2) / (2 * IMG_H), 0), 1)
            width    = min(max((x2 - x1) / IMG_W, 0), 1)
            height   = min(max((y2 - y1) / IMG_H, 0), 1)

            yolo_lines.append(
                f"{CLASS_MAP[cat]} {x_center:.6f} {y_center:.6f} {width:.6f} {height:.6f}"
            )

        if not yolo_lines:
            skipped += 1
            continue

        base_name = jf.replace('.json', '')
        img_name  = base_name + '.jpg'
        src_img   = os.path.join(img_src_dir, img_name)

        if not os.path.exists(src_img):
            skipped += 1
            continue

        txt_path = os.path.join(out_lbl_dir, base_name + '.txt')
        with open(txt_path, 'w') as f:
            f.write('\n'.join(yolo_lines))

        shutil.copy2(src_img, os.path.join(out_img_dir, img_name))
        converted += 1

        if (i + 1) % 2000 == 0:
            print(f'  {i+1}/{len(json_files)}...')

    print(f'{split.upper()} — Convertis : {converted} | Ignorés : {skipped}')
    return converted


print('=== Conversion TRAIN ===')
n_train = convert_split(TRAIN_LBL, TRAIN_IMG, OUT_TRAIN_LBL, OUT_TRAIN_IMG, 'train')

print('\n=== Conversion VAL ===')
n_val = convert_split(VAL_LBL, VAL_IMG, OUT_VAL_LBL, OUT_VAL_IMG, 'val')

print(f'\nDataset converti : {n_train} train | {n_val} val')
# Out:
# === Conversion TRAIN ===
# Conversion train : 17414 fichiers...
#   2000/17414...
#   4000/17414...
#   6000/17414...
#   8000/17414...
#   10000/17414...
#   12000/17414...
#   14000/17414...
#   16000/17414...
# TRAIN — Convertis : 17413 | Ignorés : 1
#
# === Conversion VAL ===
# Conversion val : 2499 fichiers...
#   2000/2499...
# VAL — Convertis : 2499 | Ignorés : 0
#
# Dataset converti : 17413 train | 2499 val

# %%
yaml_content = """# Dataset BDD100K — Scénario Autoroute
# Filtré sur scene=highway | 7 classes

path: /kaggle/working/dataset
train: images/train
val: images/val

nc: 7

names:
  0: car
  1: truck
  2: bus
  3: pedestrian
  4: rider
  5: traffic sign
  6: traffic light
"""

YAML_PATH = '/kaggle/working/dataset_autoroute.yaml'
with open(YAML_PATH, 'w') as f:
    f.write(yaml_content)

print('dataset_autoroute.yaml créé')
print(yaml_content)
# Out:
# dataset_autoroute.yaml créé
# # Dataset BDD100K — Scénario Autoroute
# # Filtré sur scene=highway | 7 classes
#
# path: /kaggle/working/dataset
# train: images/train
# val: images/val
#
# nc: 7
#
# names:
#   0: car
#   1: truck
#   2: bus
#   3: pedestrian
#   4: rider
#   5: traffic sign
#   6: traffic light

# %%
from ultralytics import YOLO

print('=== MODÈLE 1 : YOLOv8s — Baseline ===')

model_s = YOLO('yolov8s.pt')
results_s = model_s.train(
    data=YAML_PATH,

    epochs=80,           # Kaggle = temps limité → 80 optimal
    imgsz=640,           # 1280 trop lent sur Kaggle
    batch=16,            # T4/P100 → max stable
    device=0,
    name='yolov8s_autoroute',

    optimizer='AdamW',
    lr0=0.001,
    lrf=0.1,
    momentum=0.937,
    weight_decay=0.0005,
    warmup_epochs=3,    
    cos_lr=True,         
    hsv_h=0.015,
    hsv_s=0.5,
    hsv_v=0.4,

    fliplr=0.0,         
    mosaic=0.7,
    mixup=0.1,
    copy_paste=0.1,

    translate=0.1,
    scale=0.5,
    degrees=0.0,

    close_mosaic=10,    

    save_period=10,    
    plots=True,
    verbose=True,

    patience=20,
)

map50_s   = results_s.results_dict.get('metrics/mAP50(B)', 0)
map5095_s = results_s.results_dict.get('metrics/mAP50-95(B)', 0)
prec_s    = results_s.results_dict.get('metrics/precision(B)', 0)
rec_s     = results_s.results_dict.get('metrics/recall(B)', 0)

print(f'mAP@0.5      : {map50_s:.4f}')
print(f'mAP@0.5:0.95 : {map5095_s:.4f}')
print(f'Précision    : {prec_s:.4f}')
print(f'Rappel       : {rec_s:.4f}')
import shutil
shutil.copy(
    '/kaggle/working/runs/detect/yolov8s_autoroute/weights/best.pt',
    '/kaggle/working/best_yolov8s.pt'
)
print('✅ YOLOv8s sauvegardé dans Output !')
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# === MODÈLE 1 : YOLOv8s — Baseline ===
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s.pt to 'yolov8s.pt': 100% ━━━━━━━━━━━━ 21.5MB 149.8MB/s 0.1s
# Ultralytics 8.4.34 🚀 Python-3.12.12 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# engine/trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.1, copy_paste_mode=flip, cos_lr=True, cutmix=0.0, data=/kaggle/working/dataset_autoroute.yaml, degrees=0.0, deterministic=True, device=0, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=80, erasing=0.4, exist_ok=False, fliplr=0.0, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.5, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.001, lrf=0.1, mask_ratio=4, max_det=300, mixup=0.1, mode=train, model=yolov8s.pt, momentum=0.937, mosaic=0.7, multi_scale=0.0, name=yolov8s_autoroute, nbs=64, nms=False, opset=None, optimize=False, optimizer=AdamW, overlap_mask=True, patience=20, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=/kaggle/working/runs/detect/yolov8s_autoroute, save_frames=False, save_json=False, save_period=10, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf': 100% ━━━━━━━━━━━━ 755.1KB 17.1MB/s 0.0s
# Overriding model.yaml nc=80 with nc=7
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.conv.Conv             [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   2                  -1  1     29056  ultralytics.nn.modules.block.C2f             [64, 64, 1, True]
#   3                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   4                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   5                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   6                  -1  2    788480  ultralytics.nn.modules.block.C2f             [256, 256, 2, True]
#   7                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   8                  -1  1   1838080  ultralytics.nn.modules.block.C2f             [512, 512, 1, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    591360  ultralytics.nn.modules.block.C2f             [768, 256, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  16                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  19                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1   1969152  ultralytics.nn.modules.block.C2f             [768, 512, 1]
#  22        [15, 18, 21]  1   2118757  ultralytics.nn.modules.head.Detect           [7, 16, None, [128, 256, 512]]
# Model summary: 130 layers, 11,138,309 parameters, 11,138,293 gradients, 28.7 GFLOPs
#
# Transferred 349/355 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo26n.pt to 'yolo26n.pt': 100% ━━━━━━━━━━━━ 5.3MB 71.4MB/s 0.1s
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1391.6±734.0 MB/s, size: 53.1 KB)
# train: Scanning /kaggle/working/dataset/labels/train... 17413 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 17413/17413 1.3Kit/s 13.3s
# train: /kaggle/working/dataset/images/train/75055858-7d04a650.jpg: 1 duplicate labels removed
# train: New cache created: /kaggle/working/dataset/labels/train.cache
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 683.6±274.9 MB/s, size: 40.8 KB)
# val: Scanning /kaggle/working/dataset/labels/val... 2499 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 2499/2499 1.2Kit/s 2.1s
# val: New cache created: /kaggle/working/dataset/labels/val.cache
# optimizer: AdamW(lr=0.001, momentum=0.937) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias(decay=0.0)
# Plotting labels to /kaggle/working/runs/detect/yolov8s_autoroute/labels.jpg...
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to /kaggle/working/runs/detect/yolov8s_autoroute
# Starting training for 80 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/80      4.97G      1.549       1.15      1.025        179        640: 100% ━━━━━━━━━━━━ 1089/1089 3.7it/s 4:54
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 79/79 4.7it/s 16.9s
#                    all       2499      35860      0.544      0.315      0.305      0.167
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/80      5.66G      1.527      1.031      1.009        144        640: 100% ━━━━━━━━━━━━ 1089/1089 3.7it/s 4:54
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 79/79 5.3it/s 14.9s
#                    all       2499      35860       0.42       0.35      0.344      0.191
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/80      5.66G      1.515      1.001      1.003         74        640: 100% ━━━━━━━━━━━━ 1089/1089 3.7it/s 4:52
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 79/79 5.2it/s 15.3s
#                    all       2499      35860       0.46      0.354      0.354      0.195
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/80      5.66G      1.491     0.9698     0.9944        263        640: 100% ━━━━━━━━━━━━ 1089/1089 3.7it/s 4:51
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 79/79 5.2it/s 15.2s
#                    all       2499      35860      0.502      0.368       0.38      0.211
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/80      6.02G      1.464     0.9379     0.9854         52        640: 100% ━━━━━━━━━━━━ 1089/1089 3.7it/s 4:51
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 79/79 5.3it/s 14.9s
#                    all       2499      35860       0.54       0.37      0.388      0.215
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/80      6.02G      1.446     0.9115     0.9798        119        640: 100% ━━━━━━━━━━━━ 1089/1089 3.7it/s 4:51
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 79/79 5.3it/s 14.9s
#                    all       2499      35860      0.503      0.382      0.395      0.219
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/80      6.02G      1.438     0.8993     0.9755        135        640: 100% ━━━━━━━━━━━━ 1089/1089 3.7it/s 4:51
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 79/79 5.3it/s 15.0s
#                    all       2499      35860      0.508      0.398      0.404      0.226
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/80      6.02G      1.427     0.8888     0.9706         83        640: 100% ━━━━━━━━━━━━ 1089/1089 3.7it/s 4:51
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 79/79 5.3it/s 15.0s
#                    all       2499      35860      0.521      0.391      0.401      0.226
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/80      6.02G      1.418     0.8739     0.9675         95        640: 100% ━━━━━━━━━━━━ 1089/1089 3.7it/s 4:51
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 79/79 5.3it/s 14.9s
#                    all       2499      35860      0.558      0.386      0.415      0.234
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/80      6.02G      1.407      0.865     0.9659        118        640: 100% ━━━━━━━━━━━━ 1089/1089 3.7it/s 4:52
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 79/79 5.3it/s 15.0s
#                    all       2499      35860      0.537      0.406      0.429      0.243
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/80      6.02G      1.403     0.8587     0.9625        131        640: 100% ━━━━━━━━━━━━ 1089/1089 3.7it/s 4:51
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 79/79 5.3it/s 15.0s
#                    all       2499      35860      0.557      0.419      0.431      0.243
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       12/80      6.02G      1.398     0.8511     0.9619        182        640: 100% ━━━━━━━━━━━━ 1089/1089 3.7it/s 4:51
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 79/79 5.3it/s 14.9s
#                    all       2499      35860       0.57      0.403      0.445      0.254
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       13/80      6.02G      1.391     0.8435     0.9577        147        640: 100% ━━━━━━━━━━━━ 1089/1089 3.7it/s 4:51
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 79/79 5.4it/s 14.7s
#                    all       2499      35860      0.686      0.405      0.443      0.251
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       14/80      6.02G      1.384      0.834     0.9568        120        640: 100% ━━━━━━━━━━━━ 1089/1089 3.7it/s 4:51
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 79/79 5.3it/s 14.8s
#                    all       2499      35860      0.603      0.431      0.463      0.264
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       15/80      6.02G      1.386     0.8286      0.955         92        640: 100% ━━━━━━━━━━━━ 1089/1089 3.7it/s 4:51
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 79/79 5.4it/s 14.8s
#                    all       2499      35860      0.535      0.444      0.456      0.259
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       16/80      6.02G      1.375       0.82     0.9522        111        640: 100% ━━━━━━━━━━━━ 1089/1089 3.7it/s 4:51
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 79/79 5.3it/s 15.0s
#                    all       2499      35860      0.558      0.431      0.465      0.266
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       17/80      6.02G       1.37     0.8158     0.9514        176        640: 100% ━━━━━━━━━━━━ 1089/1089 3.7it/s 4:51
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 79/79 5.3it/s 14.9s
#                    all       2499      35860      0.616      0.436      0.469      0.268
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       18/80      6.02G       1.36     0.8101     0.9485         87        640: 100% ━━━━━━━━━━━━ 1089/1089 3.7it/s 4:51
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 79/79 5.4it/s 14.8s
#                    all       2499      35860      0.603      0.436      0.471      0.271
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       19/80      6.02G      1.363      0.808     0.9493         96        640: 100% ━━━━━━━━━━━━ 1089/1089 3.7it/s 4:52
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 79/79 5.4it/s 14.7s
#                    all       2499      35860      0.642       0.44      0.482      0.274
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       20/80      6.02G       1.36     0.8028     0.9465         75        640: 100% ━━━━━━━━━━━━ 1089/1089 3.7it/s 4:51
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 79/79 5.3it/s 14.8s
#                    all       2499      35860      0.602      0.438      0.478      0.275
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       21/80      6.39G      1.357     0.7979     0.9441        163        640: 100% ━━━━━━━━━━━━ 1089/1089 3.7it/s 4:51
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 79/79 5.3it/s 14.9s
#                    all       2499      35860      0.602      0.433      0.479      0.276
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       22/80      6.39G      1.353     0.7932     0.9445         56        640: 100% ━━━━━━━━━━━━ 1089/1089 3.7it/s 4:51
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 79/79 5.3it/s 14.8s
#                    all       2499      35860      0.636      0.438      0.491      0.281
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       23/80      6.39G      1.347     0.7867     0.9426         65        640: 100% ━━━━━━━━━━━━ 1089/1089 3.7it/s 4:52
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 79/79 5.4it/s 14.7s
#                    all       2499      35860      0.594      0.445      0.486       0.28
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       24/80      6.39G      1.343     0.7858     0.9409         88        640: 100% ━━━━━━━━━━━━ 1089/1089 3.7it/s 4:51
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 79/79 5.3it/s 15.0s
#                    all       2499      35860      0.612      0.438      0.487      0.282
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       25/80      6.39G      1.335     0.7778     0.9386        132        640: 100% ━━━━━━━━━━━━ 1089/1089 3.7it/s 4:51
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 79/79 5.4it/s 14.6s
#                    all       2499      35860      0.587      0.461      0.493      0.285
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       26/80      6.39G      1.336     0.7738     0.9381         77        640: 100% ━━━━━━━━━━━━ 1089/1089 3.7it/s 4:52
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 79/79 5.3it/s 14.8s
#                    all       2499      35860      0.597      0.451      0.494      0.285
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       27/80      6.39G      1.332     0.7697     0.9378        177        640: 100% ━━━━━━━━━━━━ 1089/1089 3.7it/s 4:51
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 79/79 5.2it/s 15.1s
#                    all       2499      35860      0.641      0.447      0.496      0.284
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       28/80
0.303
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       65/80      6.77G      1.242     0.6601     0.9065        226        640: 100% ━━━━━━━━━━━━ 1089/1089 3.7it/s 4:53
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 79/79 5.4it/s 14.6s
#                    all       2499      35860      0.609      0.476      0.516      0.302
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       66/80      6.77G      1.237     0.6591     0.9059        138        640: 100% ━━━━━━━━━━━━ 1089/1089 3.7it/s 4:52
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 79/79 5.2it/s 15.1s
#                    all       2499      35860      0.605      0.476      0.517      0.302
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       67/80      6.77G      1.238     0.6579     0.9047         77        640: 100% ━━━━━━━━━━━━ 1089/1089 3.7it/s 4:53
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 79/79 5.3it/s 15.0s
#                    all       2499      35860      0.602       0.48      0.517      0.302
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       68/80      6.77G      1.237      0.655     0.9044        188        640: 100% ━━━━━━━━━━━━ 1089/1089 3.7it/s 4:53
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 79/79 5.2it/s 15.3s
#                    all       2499      35860      0.601       0.48      0.517      0.302
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       69/80      6.77G      1.238     0.6548     0.9041         93        640: 100% ━━━━━━━━━━━━ 1089/1089 3.7it/s 4:53
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 79/79 5.4it/s 14.7s
#                    all       2499      35860      0.605      0.478      0.517      0.302
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       70/80      6.77G      1.236      0.652     0.9039        142        640: 100% ━━━━━━━━━━━━ 1089/1089 3.7it/s 4:53
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 79/79 5.3it/s 14.8s
#                    all       2499      35860      0.597       0.49      0.517      0.302
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       71/80      6.77G      1.215     0.6144     0.8957         69        640: 100% ━━━━━━━━━━━━ 1089/1089 3.8it/s 4:44
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 79/79 5.1it/s 15.6s
#                    all       2499      35860      0.599       0.49      0.517      0.302
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       72/80      6.77G       1.21     0.6103     0.8946         52        640: 100% ━━━━━━━━━━━━ 1089/1089 3.9it/s 4:43
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 79/79 5.4it/s 14.7s
#                    all       2499      35860        0.6      0.488      0.517      0.302
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       73/80      6.77G      1.209     0.6077     0.8943         37        640: 100% ━━━━━━━━━━━━ 1089/1089 3.9it/s 4:43
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 79/79 5.1it/s 15.4s
#                    all       2499      35860      0.602      0.485      0.517      0.302
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       74/80      6.77G      1.207      0.606     0.8937         89        640: 100% ━━━━━━━━━━━━ 1089/1089 3.9it/s 4:43
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 79/79 5.4it/s 14.6s
#                    all       2499      35860      0.602      0.486      0.516      0.301
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       75/80      6.77G      1.206     0.6042     0.8929         68        640: 100% ━━━━━━━━━━━━ 1089/1089 3.8it/s 4:43
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 79/79 5.2it/s 15.3s
#                    all       2499      35860      0.604      0.485      0.516      0.301
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       76/80      6.77G      1.203     0.6032     0.8926         62        640: 100% ━━━━━━━━━━━━ 1089/1089 3.9it/s 4:43
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 79/79 5.3it/s 14.9s
#                    all       2499      35860      0.602      0.486      0.516      0.301
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       77/80      6.77G      1.202     0.6019     0.8927         34        640: 100% ━━━━━━━━━━━━ 1089/1089 3.9it/s 4:43
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 79/79 5.4it/s 14.6s
#                    all       2499      35860      0.602      0.486      0.516      0.301
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       78/80      6.77G      1.198     0.6002     0.8909         69        640: 100% ━━━━━━━━━━━━ 1089/1089 3.9it/s 4:42
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 79/79 5.1it/s 15.3s
#                    all       2499      35860        0.6      0.487      0.515        0.3
# EarlyStopping: Training stopped early as no improvement observed in last 20 epochs. Best results observed at epoch 58, best model saved as best.pt.
# To update EarlyStopping(patience=20) pass a new patience value, i.e. `patience=300` or use `patience=0` to disable EarlyStopping.
#
# 78 epochs completed in 6.653 hours.
# Optimizer stripped from /kaggle/working/runs/detect/yolov8s_autoroute/weights/last.pt, 22.5MB
# Optimizer stripped from /kaggle/working/runs/detect/yolov8s_autoroute/weights/best.pt, 22.5MB
#
# Validating /kaggle/working/runs/detect/yolov8s_autoroute/weights/best.pt...
# Ultralytics 8.4.34 🚀 Python-3.12.12 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# Model summary (fused): 73 layers, 11,128,293 parameters, 0 gradients, 28.5 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 79/79 4.5it/s 17.5s
#                    all       2499      35860      0.614      0.475      0.515      0.303
#                    car       2448      22364      0.771      0.668      0.734      0.435
#                  truck        647       1033      0.668      0.512      0.567      0.391
#                    bus        235        293      0.626      0.462      0.499      0.385
#                  rider         42         52      0.257     0.0601     0.0805     0.0369
#           traffic sign       2113       9303      0.732      0.647      0.697      0.389
#          traffic light        732       2815      0.629      0.498      0.514      0.183
# Speed: 0.1ms preprocess, 2.6ms inference, 0.0ms loss, 1.0ms postprocess per image
# Results saved to /kaggle/working/runs/detect/yolov8s_autoroute
# mAP@0.5      : 0.5154
# mAP@0.5:0.95 : 0.3033
# Précision    : 0.6138
# Rappel       : 0.4747
# ✅ YOLOv8s sauvegardé dans Output !

# %%
import os
for root, dirs, files in os.walk('/kaggle/working/runs'):
    for f in files:
        if f.endswith('.pt'):
            print(os.path.join(root, f))
# Out:
# /kaggle/working/runs/detect/yolov8s_autoroute/weights/epoch50.pt
# /kaggle/working/runs/detect/yolov8s_autoroute/weights/epoch60.pt
# /kaggle/working/runs/detect/yolov8s_autoroute/weights/epoch30.pt
# /kaggle/working/runs/detect/yolov8s_autoroute/weights/last.pt
# /kaggle/working/runs/detect/yolov8s_autoroute/weights/epoch70.pt
# /kaggle/working/runs/detect/yolov8s_autoroute/weights/epoch20.pt
# /kaggle/working/runs/detect/yolov8s_autoroute/weights/epoch0.pt
# /kaggle/working/runs/detect/yolov8s_autoroute/weights/epoch40.pt
# /kaggle/working/runs/detect/yolov8s_autoroute/weights/epoch10.pt
# /kaggle/working/runs/detect/yolov8s_autoroute/weights/best.pt
